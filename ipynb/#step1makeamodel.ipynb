# %% [markdown]
# ---------
# # 배추가격 예측 AI Project for 모인활
#
# Notes by kjune18@naver.com, Handong Global Univ.

# %% [markdown]
# ## 기대효과

# %% [markdown]
# - 선형 회귀까지만 공부한 사람도 실제로 기상청 등의 데이터에서 다양한 배추 가격 데이터를 수집하고 직접 활용하여 스스로 웹사이트까지 구축해볼 수 있다.
# - 결과적으로 사용자의 입력값에 따라 적당한 배추 가격을 예측해주는 모델을 만들고, 모델을 통해 결과를 보여줄 수 있다.

# %% [markdown]
# ## 포함되는 개념들

# %% [markdown]
# 1. 파이썬 and Tensorflow에서 학습된 모델을 저장하고 필요에 따라서 불러오는 기능
# 2. Flask Web Server & Mdbootstrap Design Framework

# %% [markdown]
# ## 1. 선형 회귀
#
# 선형 회귀는 통계학에서 종속 변수 $y$와 한 개 이상의 독립 변수 $x$와의 선형 상관 관계를 모델링하는 회귀분석 기법이다.
# 선형 회귀는 선형 예측 함수를 사용해 회귀식을 모델링하며, 알려지지 않은 파라미터는 데이터로부터 추정한다. 이렇게 만들어진 회귀식을 선형 모델이라고 한다.
#
# 선형 회귀는 여러 사용 사례가 있지만, 대개 아래와 같은 두 가지 분류 중 하나로 요약할 수 있다.
# - 값을 예측하는 것이 목적일 경우, 선형 회귀를 사용해 데이터에 적합한 예측 모형을 개발한다. 개발한 선형 회귀식을 사용해 $y$가 없는 $x$값에 대해 $y$를 예측하기 위해 사용할 수 있다.
#
#
# - 종속 변수 $y$와 이것과 연관된 독립 변수 $X_1$,  ...   ,$X_p$
# 가 존재하는 경우에, 선형 회귀 분석을 사용해 $X_j$와 $y$의 관계를 정량화할 수 있다.
#
#
# <img src = "https://upload.wikimedia.org/wikipedia/commons/b/be/Normdist_regression.png" width=300>
# <center>그림 1: 독립변수 1개와 종속변수 1개를 가진 선형 회귀의 예

# %% [markdown]
# ## 2. 데이터 수집

# %% [markdown]
# 우리나라 정부에서는 다양한 데이터를 무료로 제공해주고 있다. 그러나, 데이터를 제공하는 정책이 서로 다를 수 있기 때문에 데이터를 수집하는 방법에 있어서는 조금씩 다르게 활용할 필요가 있다.

# %% [markdown]
# ### 기상청 자료 이용하기

# %% [markdown]
# 1. 기상자료개방포털(기후통계분석)로 이동한다.
# 2. 먼저 기온분석으로 이동하여, 원하는 기간과 지역/지점을 선택하고 csv다운로드 버튼을 눌러 데이터를 얻도록 한다.
# 3. 다음으로 강수량분석으로 이동하여, 앞에서 받은 데이터와 동일한 기간, 동일한 지역/지점을 선택하고 csv다운로드 버튼을 통해 데이터를 얻도록 한다.

# %% [markdown]
# ### 농산물유통 자료 이용하기

# %% [markdown]
# 1. 농산물유통정보사이트로 이동한다.
# 2. 가격정보에서 채소류->배추를 선택하고, 품종과 등급은 전체로 하여 조회한다.
# 3. 데이터 저장버튼을 통해 데이터를 얻도록 한다.

# %% [markdown]
# ## 3. 데이터 정제

# %% [markdown]
# 처음 수집한 data는 인공지능이 인식하기 쉬운 형태는 아니다.
# 따라서 엑셀 내부의 data를 정제함으로써 인공지능이 인식하기 쉬운 형태로 만들어 줘야 한다.
# 특히 배추의 가격은 주말 등에는 측정되지 않는 점이 있고, 몇몇 일자에는 가격이 급상승하는 data가 있기 때문에 data의 정제가 반드시 필요하다.

# %% [markdown]
# 여기에서 사용할 변인은 평균온도, 최저온도, 최고온도, 강수량 총 4가지 변인을 사용하여 가격을 예측하도록 할 것이다.
# <img src = "https://t1.daumcdn.net/cfile/tistory/99D710465B7D9A8E18" width= 300>

# %% [markdown]
# 정제된 data 링크 https://github.com/kjune18/AI-for-All

# %% [markdown]
# ## 4. 모델 만들기

# %% [markdown]
# 다변인 선형 회귀는 모델에 영향을 미치는 변인이 여러 개 일때 사용하는 모델이다. 현재 우리의 데이터에서는 변인이 '평균온도', '최저온도', 최고온도', '강수량'이므로 이 모든 요인이 '가격'에 영향을 미친다고 감안해야 한다. 따라서 가중치(Weight)을 고려했을 때 다음과 같은 수식을 세울 수 있다.

# %% [markdown]
# $H(x_1, x_2, x_3, x_4) = x_1w_1 + x_2w_2 + x_3w_3 + x_4w_4$

# %% [markdown]
# 파이썬에서 Tensorflow 라이브러리를 활용해 다변인 선형 회귀 모델을 구현한다.

# %%
# 엑셀에서 data를 읽어온다.
# pandas library: excel data를 읽어올 수 있다.
import tensorflow.compat.v1 as tf
import numpy as np
from pandas.io.parsers import read_csv
tf.disable_v2_behavior()

model = tf.global_variables_initializer()   # model 초기화하기

data = read_csv('price data.csv', sep=',')  # csv파일 읽어오기

xy = np.array(data, dtype=np.float32)    # 행렬 형태로 저장하기

# %%
# 4개의 변인을 입력을 받는다.
x_data = xy[:, 1:-1]   # slicing x

# 가격 값을 입력 받는다.
y_data = xy[:, [-1]]   # slicing y

# %% [markdown]
# placeholder의 전달 파라미터는 다음과 같다.
#
# placeholder(
#     dtype,
#     shape=None,
#     name=None
# )
#
#
# - dtype : 데이터 타입을 의미하며 반드시 적어주어야 한다.
#
# - shape : 입력 데이터의 형태를 의미한다. 상수 값이 될 수도 있고 다차원 배열의 정보가 들어올 수도 있다. ( 디폴트 파라미터로 None 지정 )
#
# - name : 해당 placeholder의 이름을 부여하는 것으로 적지 않아도 된다.  ( 디폴트 파라미터로 None 지정 )
#
# 텐서플로우 random_normal():
# 0~1 사이의 정규확률분포 값을 생성해주는 함수.
# 원하는 shape 대로 만들어줌

# %%
# placeholder를 설정한다.

X = tf.placeholder(tf.float32, shape=[None, 4])  # 변인 4개
Y = tf.placeholder(tf.float32, shape=[None, 1])  # 변인 1개
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %% [markdown]
# W(가중치) 값과 b(바이어스) 의 값을 지정해야 하는데 이는 학습을 위해 임의의 값 (아직 잘 모른다고 가정)을 던져준다.
#
# 텐서플로우에서는 W와 b에 해당하는 변수를 Variable 을 사용하여 나타낸다. 그리고 텐서 플로우가 알아서 이 값을 자동으로 조절해 줄 것이며 나중에 비용함수가 최소(minimize)가 되는 가중치와 바이어스 값으로 조정하게 된다.

# %%
# 가설을 설정한다.
hypothesis = tf.matmul(X, W) + b  # 행렬 곱 연산

# %%
# 비용함수를 설정한다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정한다. 여기선 GradientDescent(경사하강) 함수 사용
# 학습률 0.000005로 설정한 이유 - 되도록 짧은 시간에 정확한 결과 나오게 하기 위함
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
# 세션을 생성한다.
sess = tf.Session()

# 글로벌 변수 초기화시킨다.
sess.run(tf.global_variables_initializer())

# %%
# 학습을 수행한다.
ephocs = 100000
for step in range(ephocs):
    costx, hypox, trainx = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실비용: ", costx)
        print("-배추 가격: ", hypox[0])
# Out:
# # 0  손실비용:  12469693.0
# -배추 가격:  [-7.2540846]
# # 500  손실비용:  4195323.0
# -배추 가격:  [-279.42035]
# # 1000  손실비용:  3789525.8
# -배추 가격:  [30.743702]
# # 1500  손실비용:  3472048.0
# -배추 가격:  [313.3001]
# # 2000  손실비용:  3222085.0
# -배추 가격:  [564.37476]
# # 2500  손실비용:  3024879.5
# -배추 가격:  [787.46454]
# # 3000  손실비용:  2869088.8
# -배추 가격:  [985.73627]
# # 3500  손실비용:  2745902.5
# -배추 가격:  [1161.9884]
# # 4000  손실비용:  2648435.8
# -배추 가격:  [1318.691]
# # 4500  손실비용:  2571280.8
# -배추 가격:  [1458.0306]
# # 5000  손실비용:  2510180.5
# -배추 가격:  [1581.9432]
# # 5500  손실비용:  2461775.0
# -배추 가격:  [1692.1464]
# # 6000  손실비용:  2423411.0
# -배추 가격:  [1790.1637]
# # 6500  손실비용:  2392991.8
# -배추 가격:  [1877.3463]
# # 7000  손실비용:  2368858.0
# -배추 가격:  [1954.8969]
# # 7500  손실비용:  2349699.2
# -배추 가격:  [2023.8815]
# # 8000  손실비용:  2334476.5
# -배추 가격:  [2085.2483]
# # 8500  손실비용:  2322369.2
# -배추 가격:  [2139.84]
# # 9000  손실비용:  2312727.5
# -배추 가격:  [2188.4058]
# # 9500  손실비용:  2305037.2
# -배추 가격:  [2231.611]
# # 10000  손실비용:  2298891.2
# -배추 가격:  [2270.0493]
# # 10500  손실비용:  2293967.2
# -배추 가격:  [2304.246]
# # 11000  손실비용:  2290010.5
# -배추 가격:  [2334.6707]
# # 11500  손실비용:  2286819.2
# -배추 가격:  [2361.7393]
# # 12000  손실비용:  2284234.5
# -배추 가격:  [2385.8218]
# # 12500  손실비용:  2282129.0
# -배추 가격:  [2407.2493]
# # 13000  손실비용:  2280403.2
# -배추 가격:  [2426.3147]
# # 13500  손실비용:  2278978.0
# -배추 가격:  [2443.2786]
# # 14000  손실비용:  2277790.2
# -배추 가격:  [2458.372]
# # 14500  손실비용:  2276791.0
# -배추 가격:  [2471.8027]
# # 15000  손실비용:  2275941.2
# -배추 가격:  [2483.7534]
# # 15500  손실비용:  2275209.0
# -배추 가격:  [2494.388]
# # 16000  손실비용:  2274570.0
# -배추 가격:  [2503.851]
# # 16500  손실비용:  2274005.5
# -배추 가격:  [2512.2727]
# # 17000  손실비용:  2273499.5
# -배추 가격:  [2519.768]
# # 17500  손실비용:  2273040.0
# -배추 가격:  [2526.4387]
# # 18000  손실비용:  2272617.2
# -배추 가격:  [2532.3748]
# # 18500  손실비용:  2272223.0
# -배추 가격:  [2537.6582]
# # 19000  손실비용:  2271852.5
# -배추 가격:  [2542.363]
# # 19500  손실비용:  2271500.5
# -배추 가격:  [2546.5493]
# # 20000  손실비용:  2271163.0
# -배추 가격:  [2550.277]
# # 20500  손실비용:  2270836.2
# -배추 가격:  [2553.596]
# # 21000  손실비용:  2270520.0
# -배추 가격:  [2556.5513]
# # 21500  손실비용:  2270210.0
# -배추 가격:  [2559.1816]
# # 22000  손실비용:  2269906.5
# -배추 가격:  [2561.5266]
# # 22500  손실비용:  2269607.2
# -배추 가격:  [2563.6118]
# # 23000  손실비용:  2269312.0
# -배추 가격:  [2565.474]
# # 23500  손실비용:  2269019.8
# -배추 가격:  [2567.1282]
# # 24000  손실비용:  2268729.2
# -배추 가격:  [2568.603]
# # 24500  손실비용:  2268441.5
# -배추 가격:  [2569.92]
# # 25000  손실비용:  2268155.0
# -배추 가격:  [2571.0913]
# # 25500  손실비용:  2267869.8
# -배추 가격:  [2572.137]
# # 26000  손실비용:  2267585.5
# -배추 가격:  [2573.0737]
# # 26500  손실비용:  2267302.8
# -배추 가격:  [2573.9119]
# # 27000  손실비용:  2267020.2
# -배추 가격:  [2574.649]
# # 27500  손실비용:  2266737.8
# -배추 가격:  [2575.3032]
# # 28000  손실비용:  2266457.0
# -배추 가격:  [2575.9102]
# # 28500  손실비용:  2266176.8
# -배추 가격:  [2576.4402]
# # 29000  손실비용:  2265896.2
# -배추 가격:  [2576.9238]
# # 29500  손실비용:  2265615.5
# -배추 가격:  [2577.3528]
# # 30000  손실비용:  2265336.0
# -배추 가격:  [2577.7202]
# # 30500  손실비용:  2265056.8
# -배추 가격:  [2578.0623]
# # 31000  손실비용:  2264778.0
# -배추 가격:  [2578.3916]
# # 31500  손실비용:  2264499.0
# -배추 가격:  [2578.6401]
# # 32000  손실비용:  2264220.0
# -배추 가격:  [2578.8826]
# # 32500  손실비용:  2263941.5
# -배추 가격:  [2579.125]
# # 33000  손실비용:  2263663.0
# -배추 가격:  [2579.361]
# # 33500  손실비용:  2263385.2
# -배추 가격:  [2579.5496]
# # 34000  손실비용:  2263108.0
# -배추 가격:  [2579.6807]
# # 34500  손실비용:  2262831.0
# -배추 가격:  [2579.8098]
# # 35000  손실비용:  2262554.0
# -배추 가격:  [2579.938]
# # 35500  손실비용:  2262277.0
# -배추 가격:  [2580.066]
# # 36000  손실비용:  2262000.2
# -배추 가격:  [2580.1934]
# # 36500  손실비용:  2261724.0
# -배추 가격:  [2580.3213]
# # 37000  손실비용:  2261447.5
# -배추 가격:  [2580.449]
# # 37500  손실비용:  2261171.0
# -배추 가격:  [2580.5764]
# # 38000  손실비용:  2260895.0
# -배추 가격:  [2580.6995]
# # 38500  손실비용:  2260618.0
# -배추 가격:  [2580.7498]
# # 39000  손실비용:  2260342.8
# -배추 가격:  [2580.7864]
# # 39500  손실비용:  2260067.5
# -배추 가격:  [2580.8232]
# # 40000  손실비용:  2259793.0
# -배추 가격:  [2580.8599]
# # 40500  손실비용:  2259518.2
# -배추 가격:  [2580.8926]
# # 41000  손실비용:  2259243.8
# -배추 가격:  [2580.9253]
# # 41500  손실비용:  2258969.0
# -배추 가격:  [2580.9585]
# # 42000  손실비용:  2258694.8
# -배추 가격:  [2580.9907]
# # 42500  손실비용:  2258420.8
# -배추 가격:  [2581.0242]
# # 43000  손실비용:  2258146.5
# -배추 가격:  [2581.0574]
# # 43500  손실비용:  2257872.8
# -배추 가격:  [2581.0903]
# # 44000  손실비용:  2257598.8
# -배추 가격:  [2581.1235]
# # 44500  손실비용:  2257325.0
# -배추 가격:  [2581.1567]
# # 45000  손실비용:  2257052.0
# -배추 가격:  [2581.1904]
# # 45500  손실비용:  2256778.0
# -배추 가격:  [2581.2239]
# # 46000  손실비용:  2256505.2
# -배추 가격:  [2581.2566]
# # 46500  손실비용:  2256232.2
# -배추 가격:  [2581.2905]
# # 47000  손실비용:  2255960.2
# -배추 가격:  [2581.3232]
# # 47500  손실비용:  2255688.2
# -배추 가격:  [2581.3572]
# # 48000  손실비용:  2255417.0
# -배추 가격:  [2581.3904]
# # 48500  손실비용:  2255145.5
# -배추 가격:  [2581.4238]
# # 49000  손실비용:  2254874.5
# -배추 가격:  [2581.4583]
# # 49500  손실비용:  2254603.5
# -배추 가격:  [2581.4944]
# # 50000  손실비용:  2254332.2
# -배추 가격:  [2581.5325]
# # 50500  손실비용:  2254061.5
# -배추 가격:  [2581.5706]
# # 51000  손실비용:  2253791.0
# -배추 가격:  [2581.6128]
# # 51500  손실비용:  2253520.2
# -배추 가격:  [2581.655]
# # 52000  손실비용:  2253250.0
# -배추 가격:  [2581.697]
# # 52500  손실비용:  2252979.5
# -배추 가격:  [2581.7434]
# # 53000  손실비용:  2252709.0
# -배추 가격:  [2581.7893]
# # 53500  손실비용:  2252439.5
# -배추 가격:  [2581.8354]
# # 54000  손실비용:  2252169.2
# -배추 가격:  [2581.8813]
# # 54500  손실비용:  2251900.5
# -배추 가격:  [2581.926]
# # 55000  손실비용:  2251631.5
# -배추 가격:  [2581.9707]
# # 55500  손실비용:  2251363.0
# -배추 가격:  [2582.015]
# # 56000  손실비용:  2251095.0
# -배추 가격:  [2582.0598]
# # 56500  손실비용:  2250826.5
# -배추 가격:  [2582.1084]
# # 57000  손실비용:  2250558.8
# -배추 가격:  [2582.1567]
# # 57500  손실비용:  2250290.2
# -배추 가격:  [2582.206]
# # 58000  손실비용:  2250023.0
# -배추 가격:  [2582.2517]
# # 58500  손실비용:  2249756.5
# -배추 가격:  [2582.2944]
# # 59000  손실비용:  2249489.5
# -배추 가격:  [2582.3372]
# # 59500  손실비용:  2249223.5
# -배추 가격:  [2582.3848]
# # 60000  손실비용:  2248957.0
# -배추 가격:  [2582.435]
# # 60500  손실비용:  2248691.2
# -배추 가격:  [2582.4854]
# # 61000  손실비용:  2248425.2
# -배추 가격:  [2582.536]
# # 61500  손실비용:  2248159.5
# -배추 가격:  [2582.5862]
# # 62000  손실비용:  2247893.5
# -배추 가격:  [2582.6365]
# # 62500  손실비용:  2247627.8
# -배추 가격:  [2582.6787]
# # 63000  손실비용:  2247361.8
# -배추 가격:  [2582.7117]
# # 63500  손실비용:  2247096.2
# -배추 가격:  [2582.7454]
# # 64000  손실비용:  2246830.8
# -배추 가격:  [2582.7786]
# # 64500  손실비용:  2246565.5
# -배추 가격:  [2582.8123]
# # 65000  손실비용:  2246300.5
# -배추 가격:  [2582.846]
# # 65500  손실비용:  2246035.2
# -배추 가격:  [2582.8794]
# # 66000  손실비용:  2245770.5
# -배추 가격:  [2582.9128]
# # 66500  손실비용:  2245505.8
# -배추 가격:  [2582.9473]
# # 67000  손실비용:  2245241.2
# -배추 가격:  [2582.9807]
# # 67500  손실비용:  2244976.8
# -배추 가격:  [2583.015]
# # 68000  손실비용:  2244712.0
# -배추 가격:  [2583.0486]
# # 68500  손실비용:  2244448.0
# -배추 가격:  [2583.0828]
# # 69000  손실비용:  2244183.5
# -배추 가격:  [2583.117]
# # 69500  손실비용:  2243919.8
# -배추 가격:  [2583.1506]
# # 70000  손실비용:  2243655.8
# -배추 가격:  [2583.1848]
# # 70500  손실비용:  2243392.2
# -배추 가격:  [2583.219]
# # 71000  손실비용:  2243128.5
# -배추 가격:  [2583.253]
# # 71500  손실비용:  2242865.2
# -배추 가격:  [2583.2827]
# # 72000  손실비용:  2242601.8
# -배추 가격:  [2583.3123]
# # 72500  손실비용:  2242338.2
# -배추 가격:  [2583.345]
# # 73000  손실비용:  2242076.5
# -배추 가격:  [2583.3853]
# # 73500  손실비용:  2241815.2
# -배추 가격:  [2583.4182]
# # 74000  손실비용:  2241554.2
# -배추 가격:  [2583.451]
# # 74500  손실비용:  2241293.8
# -배추 가격:  [2583.4836]
# # 75000  손실비용:  2241033.0
# -배추 가격:  [2583.5156]
# # 75500  손실비용:  2240772.5
# -배추 가격:  [2583.5432]
# # 76000  손실비용:  2240511.8
# -배추 가격:  [2583.5706]
# # 76500  손실비용:  2240251.5
# -배추 가격:  [2583.598]
# # 77000  손실비용:  2239991.5
# -배추 가격:  [2583.625]
# # 77500  손실비용:  2239731.2
# -배추 가격:  [2583.6497]
# # 78000  손실비용:  2239471.2
# -배추 가격:  [2583.6716]
# # 78500  손실비용:  2239211.5
# -배추 가격:  [2583.6938]
# # 79000  손실비용:  2238952.0
# -배추 가격:  [2583.7158]
# # 79500  손실비용:  2238692.2
# -배추 가격:  [2583.738]
# # 80000  손실비용:  2238432.8
# -배추 가격:  [2583.7598]
# # 80500  손실비용:  2238173.2
# -배추 가격:  [2583.7766]
# # 81000  손실비용:  2237913.8
# -배추 가격:  [2583.7932]
# # 81500  손실비용:  2237654.8
# -배추 가격:  [2583.81]
# # 82000  손실비용:  2237395.8
# -배추 가격:  [2583.827]
# # 82500  손실비용:  2237136.5
# -배추 가격:  [2583.8438]
# # 83000  손실비용:  2236878.0
# -배추 가격:  [2583.8604]
# # 83500  손실비용:  2236619.0
# -배추 가격:  [2583.877]
# # 84000  손실비용:  2236360.2
# -배추 가격:  [2583.889]
# # 84500  손실비용:  2236101.8
# -배추 가격:  [2583.9001]
# # 85000  손실비용:  2235843.2
# -배추 가격:  [2583.9119]
# # 85500  손실비용:  2235585.0
# -배추 가격:  [2583.9233]
# # 86000  손실비용:  2235326.5
# -배추 가격:  [2583.9348]
# # 86500  손실비용:  2235068.2
# -배추 가격:  [2583.946]
# # 87000  손실비용:  2234810.0
# -배추 가격:  [2583.9575]
# # 87500  손실비용:  2234552.2
# -배추 가격:  [2583.969]
# # 88000  손실비용:  2234294.5
# -배추 가격:  [2583.9805]
# # 88500  손실비용:  2234037.2
# -배추 가격:  [2584.0134]
# # 89000  손실비용:  2233779.5
# -배추 가격:  [2584.0476]
# # 89500  손실비용:  2233522.0
# -배추 가격:  [2584.0818]
# # 90000  손실비용:  2233266.5
# -배추 가격:  [2584.1155]
# # 90500  손실비용:  2233011.8
# -배추 가격:  [2584.1492]
# # 91000  손실비용:  2232757.5
# -배추 가격:  [2584.1821]
# # 91500  손실비용:  2232502.5
# -배추 가격:  [2584.216]
# # 92000  손실비용:  2232247.8
# -배추 가격:  [2584.25]
# # 92500  손실비용:  2231993.8
# -배추 가격:  [2584.2834]
# # 93000  손실비용:  2231739.8
# -배추 가격:  [2584.3171]
# # 93500  손실비용:  2231485.5
# -배추 가격:  [2584.3513]
# # 94000  손실비용:  2231231.8
# -배추 가격:  [2584.3848]
# # 94500  손실비용:  2230978.0
# -배추 가격:  [2584.419]
# # 95000  손실비용:  2230724.5
# -배추 가격:  [2584.4531]
# # 95500  손실비용:  2230470.2
# -배추 가격:  [2584.4873]
# # 96000  손실비용:  2230217.0
# -배추 가격:  [2584.5212]
# # 96500  손실비용:  2229963.5
# -배추 가격:  [2584.555]
# # 97000  손실비용:  2229710.5
# -배추 가격:  [2584.589]
# # 97500  손실비용:  2229457.2
# -배추 가격:  [2584.6235]
# # 98000  손실비용:  2229204.2
# -배추 가격:  [2584.6582]
# # 98500  손실비용:  2228951.5
# -배추 가격:  [2584.6924]
# # 99000  손실비용:  2228699.0
# -배추 가격:  [2584.7268]
# # 99500  손실비용:  2228446.2
# -배추 가격:  [2584.762]

# %%
# 학습된 모델을 저장한다.
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt") #tensorflow로 학습시킨 딥러닝 모델을 저장하는 방법, 학습된 모델의 variable을 저장.
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# - 학습모델을 저장하는 이유
#
# 만약 학습 모델을 저장하지 않고 사용자로부터 배추 가격 예측 요청(Request)이 발생할 때마다 매 번 학습을 해서 결과를 돌려준다면 시간이 오래 걸리고 많은 리소스가 소모 될 것이다.
#
#   따라서 오프라인(Offline)에서 주기적으로 데이터를 이용해 학습을 진행한 뒤에, 그 결과를 저장해서 서버에서는 실시간 요청에 따라 이미 저장된 학습 모델로 배추 가격을 예측하는 것이 효율적이다.

# %% [markdown]
# ## 참고자료

# %% [markdown]
# 1. 선형회귀 위키백과(https://ko.wikipedia.org/wiki/%EC%84%A0%ED%98%95_%ED%9A%8C%EA%B7%80)
# 1. 안경잡이개발자
# https://ndb796.tistory.com/124
# 1. 텐서플로우 기본 문법
# https://gdyoon.tistory.com/8
# https://gdyoon.tistory.com/5
# https://zetawiki.com/wiki/%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C%EC%9A%B0_random_normal()
